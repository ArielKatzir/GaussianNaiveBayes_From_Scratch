# %% [markdown]
# # LabSheet 1

# %%
# Libraries
import pandas as pd
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.naive_bayes import GaussianNB
import math
import numpy as np
from scipy import signal

# %%
# Setting up dataframes
fruit_dataset = pd.read_table("fruit_data_with_colors.txt")
X = fruit_dataset[['mass','width','height','color_score']]
Y = fruit_dataset['fruit_name']

fruit_dataset_train = pd.read_table("train.txt")
fruit_dataset_test = pd.read_table("test.txt")

heads = list(X.columns.values)

# random state is set to keep the results constant when testing the code
# used 0.3 for test size because thats what the question asked(70/30)
X_train,X_test,Y_train,Y_test = train_test_split(X, Y, test_size = 0.3 , random_state = 1000)

# %%
# datasizes
print(fruit_dataset.shape)
print(X.shape)
print(Y.shape)

# preprocessing
scaler = StandardScaler()
scaler.fit(X)
X_train = scaler.transform(X_train)  
X_test = scaler.transform(X_test)
# Out:
# (59, 7)
# (59, 4)
# (59,)
# c:\users\ariel\appdata\local\programs\python\python37\lib\site-packages\sklearn\preprocessing\data.py:617: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# c:\users\ariel\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:9: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   if __name__ == '__main__':
# c:\users\ariel\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:10: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   # Remove the CWD from sys.path while we load stuff.

# %%
# Finding the best k using accuracy score and confusion matrix (knn)
scores_knn = []
confusion_matrices_knn = []
for k in range(1,9):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train,Y_train)
    pred = knn.predict(X_test)
    accuracy = metrics.accuracy_score(Y_test,pred)
    matrix = confusion_matrix(Y_test,pred)
    scores_knn.append(accuracy)
    confusion_matrices_knn.append(matrix)

# %%
# finding accuracy score and confusion matrix (Guassian)
gnb = GaussianNB()
gnb.fit(X_train,Y_train)
pred = gnb.predict(X_test)
accuracy_gnb = metrics.accuracy_score(Y_test,pred)
confusion_matrix_gnb = confusion_matrix(Y_test,pred)

# %%
for i in range(len(scores_knn)):
    print("With knn, for k=" + str(i+1) + " accuracy score is " + str(round(1000*scores_knn[i])/10) + "% and the confusion matrix is " + "\n" + str(confusion_matrices_knn[i]) + "\n")
    
print("The accuracy when using the Gaussian Naïve Bayes classifier is: " + str(round(1000*accuracy_gnb)/10) + "%. And the confusion matrix is: " + "\n" + str(confusion_matrix_gnb))
# Out:
# With knn, for k=1 accuracy score is 100.0% and the confusion matrix is
# [[8 0 0 0]
#  [0 3 0 0]
#  [0 0 2 0]
#  [0 0 0 5]]
#
# With knn, for k=2 accuracy score is 94.4% and the confusion matrix is
# [[8 0 0 0]
#  [0 3 0 0]
#  [0 0 2 0]
#  [1 0 0 4]]
#
# With knn, for k=3 accuracy score is 94.4% and the confusion matrix is
# [[7 0 0 1]
#  [0 3 0 0]
#  [0 0 2 0]
#  [0 0 0 5]]
#
# With knn, for k=4 accuracy score is 94.4% and the confusion matrix is
# [[8 0 0 0]
#  [0 3 0 0]
#  [0 0 2 0]
#  [1 0 0 4]]
#
# With knn, for k=5 accuracy score is 88.9% and the confusion matrix is
# [[6 0 0 2]
#  [0 3 0 0]
#  [0 0 2 0]
#  [0 0 0 5]]
#
# With knn, for k=6 accuracy score is 83.3% and the confusion matrix is
# [[6 0 0 2]
#  [0 3 0 0]
#  [0 0 2 0]
#  [1 0 0 4]]
#
# With knn, for k=7 accuracy score is 77.8% and the confusion matrix is
# [[5 0 0 3]
#  [0 3 0 0]
#  [0 0 2 0]
#  [1 0 0 4]]
#
# With knn, for k=8 accuracy score is 77.8% and the confusion matrix is
# [[5 0 0 3]
#  [0 3 0 0]
#  [0 0 2 0]
#  [1 0 0 4]]
#
# The accuracy when using the Gaussian Naïve Bayes classifier is: 94.4%. And the confusion matrix is:
# [[8 0 0 0]
#  [0 3 0 0]
#  [0 0 2 0]
#  [1 0 0 4]]

# %% [markdown]
# ### We’re only looking for argmaxc(P(d|c) * P(c))
# ##### P(c) is the prior probability and is calculated by dividing the number of times a class member appears in our training data by the total size of the training data.

# %%
# Function to return probability of a class member being in the dataset. Parameter - fruit label (int from 1 - 4)
def P_c (label):
    label+=1
    counter = 0
    for entry in fruit_dataset['fruit_label']:
        if entry == label:
            counter+=1
    return counter/ fruit_dataset.shape[0]

# %%
#  spliiting the train data to their classes
classes = []
# find number of classes
no_classes = max(fruit_dataset['fruit_label'])

# creating df for each class
for i in range(no_classes):
    Class = fruit_dataset.loc[fruit_dataset['fruit_label'] == i+1]
    classes.append(Class)
print(classes)
# Out:
# [    fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# 11            1      apple          braeburn   172    7.1     7.6         0.92
# 12            1      apple          braeburn   154    7.0     7.1         0.88
# 13            1      apple  golden_delicious   164    7.3     7.7         0.70
# 14            1      apple  golden_delicious   152    7.6     7.3         0.69
# 15            1      apple  golden_delicious   156    7.7     7.1         0.69
# 16            1      apple  golden_delicious   156    7.6     7.5         0.67
# 17            1      apple  golden_delicious   168    7.5     7.6         0.73
# 18            1      apple       cripps_pink   162    7.5     7.1         0.83
# 19            1      apple       cripps_pink   162    7.4     7.2         0.85
# 20            1      apple       cripps_pink   160    7.5     7.5         0.86
# 21            1      apple       cripps_pink   156    7.4     7.4         0.84
# 22            1      apple       cripps_pink   140    7.3     7.1         0.87
# 23            1      apple       cripps_pink   170    7.6     7.9         0.88,    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79
# 5            2   mandarin      mandarin    80    5.8     4.3         0.77
# 6            2   mandarin      mandarin    80    5.9     4.3         0.81
# 7            2   mandarin      mandarin    76    5.8     4.0         0.81,     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 24            3     orange     spanish_jumbo   342    9.0     9.4         0.75
# 25            3     orange     spanish_jumbo   356    9.2     9.2         0.75
# 26            3     orange     spanish_jumbo   362    9.6     9.2         0.74
# 27            3     orange  selected_seconds   204    7.5     9.2         0.77
# 28            3     orange  selected_seconds   140    6.7     7.1         0.72
# 29            3     orange  selected_seconds   160    7.0     7.4         0.81
# 30            3     orange  selected_seconds   158    7.1     7.5         0.79
# 31            3     orange  selected_seconds   210    7.8     8.0         0.82
# 32            3     orange  selected_seconds   164    7.2     7.0         0.80
# 33            3     orange      turkey_navel   190    7.5     8.1         0.74
# 34            3     orange      turkey_navel   142    7.6     7.8         0.75
# 35            3     orange      turkey_navel   150    7.1     7.9         0.75
# 36            3     orange      turkey_navel   160    7.1     7.6         0.76
# 37            3     orange      turkey_navel   154    7.3     7.3         0.79
# 38            3     orange      turkey_navel   158    7.2     7.8         0.77
# 39            3     orange      turkey_navel   144    6.8     7.4         0.75
# 40            3     orange      turkey_navel   154    7.1     7.5         0.78
# 41            3     orange      turkey_navel   180    7.6     8.2         0.79
# 42            3     orange      turkey_navel   154    7.2     7.2         0.82,     fruit_label fruit_name   fruit_subtype  mass  width  height  color_score
# 43            4      lemon  spanish_belsan   194    7.2    10.3         0.70
# 44            4      lemon  spanish_belsan   200    7.3    10.5         0.72
# 45            4      lemon  spanish_belsan   186    7.2     9.2         0.72
# 46            4      lemon  spanish_belsan   216    7.3    10.2         0.71
# 47            4      lemon  spanish_belsan   196    7.3     9.7         0.72
# 48            4      lemon  spanish_belsan   174    7.3    10.1         0.72
# 49            4      lemon         unknown   132    5.8     8.7         0.73
# 50            4      lemon         unknown   130    6.0     8.2         0.71
# 51            4      lemon         unknown   116    6.0     7.5         0.72
# 52            4      lemon         unknown   118    5.9     8.0         0.72
# 53            4      lemon         unknown   120    6.0     8.4         0.74
# 54            4      lemon         unknown   116    6.1     8.5         0.71
# 55            4      lemon         unknown   116    6.3     7.7         0.72
# 56            4      lemon         unknown   116    5.9     8.1         0.73
# 57            4      lemon         unknown   152    6.5     8.5         0.72
# 58            4      lemon         unknown   118    6.1     8.1         0.70]

# %% [markdown]
# ####  d consists of the values (x1, x2, x3,…) and we assume the elements are independent then: P(d|c) = P(x1|c)P(x2|c)P(x3|c)…

# %%
# First - find varience and mean of each feature in each class

def mean(feature, class_id):
    mean = sum(classes[class_id][feature]) / classes[class_id].shape[0]  
    return mean

def varience(feature ,class_id):
    varience = sum((i - mean(feature, class_id)) ** 2 for i in classes[class_id][feature]) / len(classes[class_id][feature]) 
    print( "var:" + str(varience) + "   feature: " +str(feature) + "   class: " + str(class_id))
    print("mean: " + str(mean(feature, class_id)))
    return varience

# %%
# To find P(d|c) apply Guassian distribution with the pdf
def gaussian(x, mean, varience):
    return (1/math.sqrt(2*3.14*varience) * math.exp(-0.5 * math.pow((x - mean),2)/varience))

# Change the function for ease of use
def gaus(x , feature , class_id):
    return gaussian(x , mean(feature , class_id) ,varience (feature, class_id))
#     print("gaus: " + str(gaussian(x , mean(feature , class_id) ,varience (feature, class_id))))

# %%
# create the classifier

def Gaussian_classifier_fruits(test_vectors):
    test_vectors = test_vectors[['mass','width','height','color_score']]
    predictions = []
    for row in range(test_vectors.shape[0]):
        results = []
        for class_id in range(len(classes)):
            prob = 1
            for head in heads:
                print("prob: " + str(prob))
                print("x: " + str(X[head][row]))
                prob = prob * gaus (X[head][row] ,head, class_id)
            print("final prob: " + str(prob))    
            print( "pc: " + str(P_c(class_id)))
            print("prob times Pc: " + str(prob * P_c(class_id)))
            print("")
            results.append(prob * P_c(class_id))
        predictions.append(results.index(max(results)) + 1)
        print(results)
    return predictions

# %%
X = fruit_dataset_test[['mass','width','height','color_score']]
Y = fruit_dataset_test['fruit_label']
gnb = GaussianNB()
gnb.fit(X,Y)
pred = gnb.predict(X)

print("mine: " + str(Gaussian_classifier_fruits(fruit_dataset_test)))
print("sklearn: " + str(pred))
# Out:
# prob: 1
# x: 180
# var:135.73407202216066   feature: mass   class: 0
# mean: 165.05263157894737
# prob: 0.015039815801392806
# x: 8.0
# var:0.11296398891966761   feature: width   class: 0
# mean: 7.457894736842104
# prob: 0.004862725100305226
# x: 6.8
# var:0.08033240997229923   feature: height   class: 0
# mean: 7.342105263157895
# prob: 0.0010991829640793476
# x: 0.59
# var:0.014612742382271475   feature: color_score   class: 0
# mean: 0.7836842105263158
# final prob: 0.0010052353494860566
# pc: 0.3220338983050847
# prob times Pc: 0.00032371985830906904
#
# prob: 1
# x: 180
# var:12.16   feature: mass   class: 1
# mean: 81.2
# prob: 5.541224129991721e-176
# x: 8.0
# var:0.022400000000000034   feature: width   class: 1
# mean: 5.9399999999999995
# prob: 1.0758026587936924e-216
# x: 6.8
# var:0.0616   feature: height   class: 1
# mean: 4.380000000000001
# prob: 3.921606626181988e-237
# x: 0.59
# var:0.0002240000000000004   feature: color_score   class: 1
# mean: 0.796
# final prob: 7.613615216094691e-277
# pc: 0.0847457627118644
# prob times Pc: 6.452216284826008e-278
#
# prob: 1
# x: 180
# var:5136.797783933517   feature: mass   class: 2
# mean: 193.78947368421052
# prob: 0.005465573923227053
# x: 8.0
# var:0.6277008310249305   feature: width   class: 2
# mean: 7.557894736842104
# prob: 0.0023559336373385853
# x: 6.8
# var:0.5612742382271466   feature: height   class: 2
# mean: 7.936842105263156
# prob: 0.00039681194422775063
# x: 0.59
# var:0.0007988919667590031   feature: color_score   class: 2
# mean: 0.7710526315789474
# final prob: 6.89282069308799e-12
# pc: 0.3220338983050847
# prob times Pc: 2.2197219181130813e-12
#
# prob: 1
# x: 180
# var:1317.5   feature: mass   class: 3
# mean: 150.0
# prob: 0.007812841071837117
# x: 8.0
# var:0.36609375   feature: width   class: 3
# mean: 6.512499999999999
# prob: 0.0002509594841606762
# x: 6.8
# var:0.9337109374999999   feature: height   class: 3
# mean: 8.856250000000001
# prob: 1.0769616104176308e-05
# x: 0.59
# var:0.00010273437500000018   feature: color_score   class: 3
# mean: 0.718125
# final prob: 8.496009256016861e-39
# pc: 0.2711864406779661
# prob times Pc: 2.3040025101062675e-39
#
# [0.00032371985830906904, 6.452216284826008e-278, 2.2197219181130813e-12, 2.3040025101062675e-39]
# prob: 1
# x: 176
# var:135.73407202216066   feature: mass   class: 0
# mean: 165.05263157894737
# prob: 0.022026628143435416
# x: 7.4
# var:0.11296398891966761   feature: width   class: 0
# mean: 7.457894736842104
# prob: 0.02576648184969392
# x: 7.2
# var:0.08033240997229923   feature: height   class: 0
# mean: 7.342105263157895
# prob: 0.031992161284879535
# x: 0.6
# var:0.014612742382271475   feature: color_score   class: 0
# mean: 0.7836842105263158
# final prob: 0.033290382057430824
# pc: 0.3220338983050847
# prob times Pc: 0.010720631510020095
#
# prob: 1
# x: 176
# var:12.16   feature: mass   class: 1
# mean: 81.2
# prob: 3.7364254773568506e-162
# x: 7.4
# var:0.022400000000000034   feature: width   class: 1
# mean: 5.9399999999999995
# prob: 2.160060620888827e-182
# x: 7.2
# var:0.0616   feature: height   class: 1
# mean: 4.380000000000001
# prob: 3.217740179746087e-210
# x: 0.6
# var:0.0002240000000000004   feature: color_score   class: 1
# mean: 0.796
# final prob: 4.928279376292788e-246
# pc: 0.0847457627118644
# prob times Pc: 4.176507946010837e-247
#
# prob: 1
# x: 176
# var:5136.797783933517   feature: mass   class: 2
# mean: 193.78947368421052
# prob: 0.005398785096005227
# x: 7.4
# var:0.6277008310249305   feature: width   class: 2
# mean: 7.557894736842104
# prob: 0.002665724768143237
# x: 7.2
# var:0.5612742382271466   feature: height   class: 2
# mean: 7.936842105263156
# prob: 0.000875377387336614
# x: 0.6
# var:0.0007988919667590031   feature: color_score   class: 2
# mean: 0.7710526315789474
# final prob: 1.3774210498991155e-10
# pc: 0.3220338983050847
# prob times Pc: 4.435762703064948e-11
#
# prob: 1
# x: 176
# var:1317.5   feature: mass   class: 3
# mean: 150.0
# prob: 0.008506054116529166
# x: 7.4
# var:0.36609375   feature: width   class: 3
# mean: 6.512499999999999
# prob: 0.0019131833084916226
# x: 7.2
# var:0.9337109374999999   feature: height   class: 3
# mean: 8.856250000000001
# prob: 0.00018184871669121012
# x: 0.6
# var:0.00010273437500000018   feature: color_score   class: 3
# mean: 0.718125
# final prob: 2.2996065575239496e-32
# pc: 0.2711864406779661
# prob times Pc: 6.236221172946305e-33
#
# [0.010720631510020095, 4.176507946010837e-247, 4.435762703064948e-11, 6.236221172946305e-33]
# prob: 1
# x: 86
# var:135.73407202216066   feature: mass   class: 0
# mean: 165.05263157894737
# prob: 3.4436719751432496e-12
# x: 6.2
# var:0.11296398891966761   feature: width   class: 0
# mean: 7.457894736842104
# prob: 3.71506456481262e-15
# x: 4.7
# var:0.08033240997229923   feature: height   class: 0
# mean: 7.342105263157895
# prob: 7.061470960081319e-34
# x: 0.8
# var:0.014612742382271475   feature: color_score   class: 0
# mean: 0.7836842105263158
# final prob: 2.309902511817405e-33
# pc: 0.3220338983050847
# prob times Pc: 7.438669105852659e-34
#
# prob: 1
# x: 86
# var:12.16   feature: mass   class: 1
# mean: 81.2
# prob: 0.044372767178279725
# x: 6.2
# var:0.022400000000000034   feature: width   class: 1
# mean: 5.9399999999999995
# prob: 0.0261633487263197
# x: 4.7
# var:0.0616   feature: height   class: 1
# mean: 4.380000000000001
# prob: 0.01832108185320264
# x: 0.8
# var:0.0002240000000000004   feature: color_score   class: 1
# mean: 0.796
# final prob: 0.4713426799361691
# pc: 0.0847457627118644
# prob times Pc: 0.03994429490984484
#
# prob: 1
# x: 86
# var:5136.797783933517   feature: mass   class: 2
# mean: 193.78947368421052
# prob: 0.001796898269880143
# x: 6.2
# var:0.6277008310249305   feature: width   class: 2
# mean: 7.557894736842104
# prob: 0.0002083506697481251
# x: 4.7
# var:0.5612742382271466   feature: height   class: 2
# mean: 7.936842105263156
# prob: 9.812996479100506e-09
# x: 0.8
# var:0.0007988919667590031   feature: color_score   class: 2
# mean: 0.7710526315789474
# final prob: 8.20000526352759e-08
# pc: 0.3220338983050847
# prob times Pc: 2.6406796611360033e-08
#
# prob: 1
# x: 86
# var:1317.5   feature: mass   class: 3
# mean: 150.0
# prob: 0.0023230139187840277
# x: 6.2
# var:0.36609375   feature: width   class: 3
# mean: 6.512499999999999
# prob: 0.0013407609917007262
# x: 4.7
# var:0.9337109374999999   feature: height   class: 3
# mean: 8.856250000000001
# prob: 5.3194191861989615e-08
# x: 0.8
# var:0.00010273437500000018   feature: color_score   class: 3
# mean: 0.718125
# final prob: 1.4189353750258592e-20
# pc: 0.2711864406779661
# prob times Pc: 3.847960339053177e-21
#
# [7.438669105852659e-34, 0.03994429490984484, 2.6406796611360033e-08, 3.847960339053177e-21]
# prob: 1
# x: 84
# var:135.73407202216066   feature: mass   class: 0
# mean: 165.05263157894737
# prob: 1.0586423828170054e-12
# x: 6.0
# var:0.11296398891966761   feature: width   class: 0
# mean: 7.457894736842104
# prob: 1.0318057922989211e-16
# x: 4.6
# var:0.08033240997229923   feature: height   class: 0
# mean: 7.342105263157895
# prob: 6.872521549108839e-37
# x: 0.79
# var:0.014612742382271475   feature: color_score   class: 0
# mean: 0.7836842105263158
# final prob: 2.2655709420419452e-36
# pc: 0.3220338983050847
# prob times Pc: 7.295906423524908e-37
#
# prob: 1
# x: 84
# var:12.16   feature: mass   class: 1
# mean: 81.2
# prob: 0.08289924290090228
# x: 6.0
# var:0.022400000000000034   feature: width   class: 1
# mean: 5.9399999999999995
# prob: 0.2039614400028349
# x: 4.6
# var:0.0616   feature: height   class: 1
# mean: 4.380000000000001
# prob: 0.22139214204092975
# x: 0.79
# var:0.0002240000000000004   feature: color_score   class: 1
# mean: 0.796
# final prob: 5.447029250913553
# pc: 0.0847457627118644
# prob times Pc: 0.46161264838250443
#
# prob: 1
# x: 84
# var:5136.797783933517   feature: mass   class: 2
# mean: 193.78947368421052
# prob: 0.0017223765844892297
# x: 6.0
# var:0.6277008310249305   feature: width   class: 2
# mean: 7.557894736842104
# prob: 0.00012550513491468588
# x: 4.6
# var:0.5612742382271466   feature: height   class: 2
# mean: 7.936842105263156
# prob: 3.2911208362973457e-09
# x: 0.79
# var:0.0007988919667590031   feature: color_score   class: 2
# mean: 0.7710526315789474
# final prob: 3.711412699871628e-08
# pc: 0.3220338983050847
# prob times Pc: 1.1952006999586597e-08
#
# prob: 1
# x: 84
# var:1317.5   feature: mass   class: 3
# mean: 150.0
# prob: 0.0021047437352365596
# x: 6.0
# var:0.36609375   feature: width   class: 3
# mean: 6.512499999999999
# prob: 0.0009696825952638539
# x: 4.6
# var:0.9337109374999999   feature: height   class: 3
# mean: 8.856250000000001
# prob: 2.451874651670683e-08
# x: 0.79
# var:0.00010273437500000018   feature: color_score   class: 3
# mean: 0.718125
# final prob: 1.1624502750682987e-17
# pc: 0.2711864406779661
# prob times Pc: 3.1524075256089457e-18
#
# [7.295906423524908e-37, 0.46161264838250443, 1.1952006999586597e-08, 3.1524075256089457e-18]
# prob: 1
# x: 152
# var:135.73407202216066   feature: mass   class: 0
# mean: 165.05263157894737
# prob: 0.018285888508498896
# x: 7.6
# var:0.11296398891966761   feature: width   class: 0
# mean: 7.457894736842104
# prob: 0.019854003986457806
# x: 7.3
# var:0.08033240997229923   feature: height   class: 0
# mean: 7.342105263157895
# prob: 0.02764589599839086
# x: 0.69
# var:0.014612742382271475   feature: color_score   class: 0
# mean: 0.7836842105263158
# final prob: 0.0675867591771076
# pc: 0.3220338983050847
# prob times Pc: 0.02176522753161092
#
# prob: 1
# x: 152
# var:12.16   feature: mass   class: 1
# mean: 81.2
# prob: 3.510085614184883e-91
# x: 7.6
# var:0.022400000000000034   feature: width   class: 1
# mean: 5.9399999999999995
# prob: 1.8122813118264358e-117
# x: 7.3
# var:0.0616   feature: height   class: 1
# mean: 4.380000000000001
# prob: 2.5579566110016465e-147
# x: 0.69
# var:0.0002240000000000004   feature: color_score   class: 1
# mean: 0.796
# final prob: 8.740346121027762e-157
# pc: 0.0847457627118644
# prob times Pc: 7.407072983921833e-158
#
# prob: 1
# x: 152
# var:5136.797783933517   feature: mass   class: 2
# mean: 193.78947368421052
# prob: 0.004697321333921133
# x: 7.6
# var:0.6277008310249305   feature: width   class: 2
# mean: 7.557894736842104
# prob: 0.0023625488368822617
# x: 7.3
# var:0.5612742382271466   feature: height   class: 2
# mean: 7.936842105263156
# prob: 0.000876811554491748
# x: 0.69
# var:0.0007988919667590031   feature: color_score   class: 2
# mean: 0.7710526315789474
# final prob: 0.00020277541456377554
# pc: 0.3220338983050847
# prob times Pc: 6.530055723240228e-05
#
# prob: 1
# x: 152
# var:1317.5   feature: mass   class: 3
# mean: 150.0
# prob: 0.010977048817721971
# x: 7.6
# var:0.36609375   feature: width   class: 3
# mean: 6.512499999999999
# prob: 0.0014395314394241346
# x: 7.3
# var:0.9337109374999999   feature: height   class: 3
# mean: 8.856250000000001
# prob: 0.00016251217028957846
# x: 0.69
# var:0.00010273437500000018   feature: color_score   class: 3
# mean: 0.718125
# final prob: 0.0001361748755024323
# pc: 0.2711864406779661
# prob times Pc: 3.6928779797269776e-05
#
# [0.02176522753161092, 7.407072983921833e-158, 6.530055723240228e-05, 3.6928779797269776e-05]
# prob: 1
# x: 164
# var:135.73407202216066   feature: mass   class: 0
# mean: 165.05263157894737
# prob: 0.034111679968369654
# x: 7.2
# var:0.11296398891966761   feature: width   class: 0
# mean: 7.457894736842104
# prob: 0.030171973112655598
# x: 7.0
# var:0.08033240997229923   feature: height   class: 0
# mean: 7.342105263157895
# prob: 0.02050300065661931
# x: 0.8
# var:0.014612742382271475   feature: color_score   class: 0
# mean: 0.7836842105263158
# final prob: 0.06706808395056184
# pc: 0.3220338983050847
# prob times Pc: 0.021598196526452115
#
# prob: 1
# x: 164
# var:12.16   feature: mass   class: 1
# mean: 81.2
# prob: 4.269406451640786e-124
# x: 7.2
# var:0.022400000000000034   feature: width   class: 1
# mean: 5.9399999999999995
# prob: 4.633967339683051e-139
# x: 7.0
# var:0.0616   feature: height   class: 1
# mean: 4.380000000000001
# prob: 4.724609236784359e-163
# x: 0.8
# var:0.0002240000000000004   feature: color_score   class: 1
# mean: 0.796
# final prob: 1.2154904372788664e-161
# pc: 0.0847457627118644
# prob times Pc: 1.0300766417617512e-162
#
# prob: 1
# x: 164
# var:5136.797783933517   feature: mass   class: 2
# mean: 193.78947368421052
# prob: 0.005106936409960519
# x: 7.2
# var:0.6277008310249305   feature: width   class: 2
# mean: 7.557894736842104
# prob: 0.00232270046395246
# x: 7.0
# var:0.5612742382271466   feature: height   class: 2
# mean: 7.936842105263156
# prob: 0.0005660689855359179
# x: 0.8
# var:0.0007988919667590031   feature: color_score   class: 2
# mean: 0.7710526315789474
# final prob: 0.004730225544052912
# pc: 0.3220338983050847
# prob times Pc: 0.0015232929718136496
#
# prob: 1
# x: 164
# var:1317.5   feature: mass   class: 3
# mean: 150.0
# prob: 0.01020564855412091
# x: 7.2
# var:0.36609375   feature: width   class: 3
# mean: 6.512499999999999
# prob: 0.003529475816124612
# x: 7.0
# var:0.9337109374999999   feature: height   class: 3
# mean: 8.856250000000001
# prob: 0.0002302967932425599
# x: 0.8
# var:0.00010273437500000018   feature: color_score   class: 3
# mean: 0.718125
# final prob: 6.143081702128186e-17
# pc: 0.2711864406779661
# prob times Pc: 1.6659204615940844e-17
#
# [0.021598196526452115, 1.0300766417617512e-162, 0.0015232929718136496, 1.6659204615940844e-17]
# prob: 1
# x: 356
# var:135.73407202216066   feature: mass   class: 0
# mean: 165.05263157894737
# prob: 1.6016445797428322e-60
# x: 9.2
# var:0.11296398891966761   feature: width   class: 0
# mean: 7.457894736842104
# prob: 2.787155661275039e-66
# x: 9.2
# var:0.08033240997229923   feature: height   class: 0
# mean: 7.342105263157895
# prob: 1.8332368329649823e-75
# x: 0.75
# var:0.014612742382271475   feature: color_score   class: 0
# mean: 0.7836842105263158
# final prob: 5.821195687895082e-75
# pc: 0.3220338983050847
# prob times Pc: 1.8746223401696023e-75
#
# prob: 1
# x: 356
# var:12.16   feature: mass   class: 1
# mean: 81.2
# prob: 0.0
# x: 9.2
# var:0.022400000000000034   feature: width   class: 1
# mean: 5.9399999999999995
# prob: 0.0
# x: 9.2
# var:0.0616   feature: height   class: 1
# mean: 4.380000000000001
# prob: 0.0
# x: 0.75
# var:0.0002240000000000004   feature: color_score   class: 1
# mean: 0.796
# final prob: 0.0
# pc: 0.0847457627118644
# prob times Pc: 0.0
#
# prob: 1
# x: 356
# var:5136.797783933517   feature: mass   class: 2
# mean: 193.78947368421052
# prob: 0.00042991156467352506
# x: 9.2
# var:0.6277008310249305   feature: width   class: 2
# mean: 7.557894736842104
# prob: 2.527496747518277e-05
# x: 9.2
# var:0.5612742382271466   feature: height   class: 2
# mean: 7.936842105263156
# prob: 3.2495690650252654e-06
# x: 0.75
# var:0.0007988919667590031   feature: color_score   class: 2
# mean: 0.7710526315789474
# final prob: 3.4764171696617686e-05
# pc: 0.3220338983050847
# prob times Pc: 1.1195241732809085e-05
#
# prob: 1
# x: 356
# var:1317.5   feature: mass   class: 3
# mean: 150.0
# prob: 1.1141495444583405e-09
# x: 9.2
# var:0.36609375   feature: width   class: 3
# mean: 6.512499999999999
# prob: 3.820093097932031e-14
# x: 9.2
# var:0.9337109374999999   feature: height   class: 3
# mean: 8.856250000000001
# prob: 1.4808369220391347e-14
# x: 0.75
# var:0.00010273437500000018   feature: color_score   class: 3
# mean: 0.718125
# final prob: 4.150888843861308e-15
# pc: 0.2711864406779661
# prob times Pc: 1.1256647712166258e-15
#
# [1.8746223401696023e-75, 0.0, 1.1195241732809085e-05, 1.1256647712166258e-15]
# prob: 1
# x: 160
# var:135.73407202216066   feature: mass   class: 0
# mean: 165.05263157894737
# prob: 0.03117700060975236
# x: 7.1
# var:0.11296398891966761   feature: width   class: 0
# mean: 7.457894736842104
# prob: 0.020997306943455637
# x: 7.6
# var:0.08033240997229923   feature: height   class: 0
# mean: 7.342105263157895
# prob: 0.01954138931972943
# x: 0.76
# var:0.014612742382271475   feature: color_score   class: 0
# mean: 0.7836842105263158
# final prob: 0.0632811092528024
# pc: 0.3220338983050847
# prob times Pc: 0.020378662301749926
#
# prob: 1
# x: 160
# var:12.16   feature: mass   class: 1
# mean: 81.2
# prob: 1.4909314602887722e-112
# x: 7.1
# var:0.022400000000000034   feature: width   class: 1
# mean: 5.9399999999999995
# prob: 3.589292682805948e-125
# x: 7.6
# var:0.0616   feature: height   class: 1
# mean: 4.380000000000001
# prob: 1.6270837653868852e-161
# x: 0.76
# var:0.0002240000000000004   feature: color_score   class: 1
# mean: 0.796
# final prob: 2.40410917956424e-161
# pc: 0.0847457627118644
# prob times Pc: 2.0373806606476608e-162
#
# prob: 1
# x: 160
# var:5136.797783933517   feature: mass   class: 2
# mean: 193.78947368421052
# prob: 0.004982069585370994
# x: 7.1
# var:0.6277008310249305   feature: width   class: 2
# mean: 7.557894736842104
# prob: 0.002123347477407298
# x: 7.6
# var:0.5612742382271466   feature: height   class: 2
# mean: 7.936842105263156
# prob: 0.0010222496865454262
# x: 0.76
# var:0.0007988919667590031   feature: color_score   class: 2
# mean: 0.7710526315789474
# final prob: 0.013369913062514787
# pc: 0.3220338983050847
# prob times Pc: 0.004305565223521711
#
# prob: 1
# x: 160
# var:1317.5   feature: mass   class: 3
# mean: 150.0
# prob: 0.010584323426421686
# x: 7.1
# var:0.36609375   feature: width   class: 3
# mean: 6.512499999999999
# prob: 0.004356712359355391
# x: 7.6
# var:0.9337109374999999   feature: height   class: 3
# mean: 8.856250000000001
# prob: 0.0007727681584561959
# x: 0.76
# var:0.00010273437500000018   feature: color_score   class: 3
# mean: 0.718125
# final prob: 5.98200292277851e-06
# pc: 0.2711864406779661
# prob times Pc: 1.6222380807534944e-06
#
# [0.020378662301749926, 2.0373806606476608e-162, 0.004305565223521711, 1.6222380807534944e-06]
# prob: 1
# x: 196
# var:135.73407202216066   feature: mass   class: 0
# mean: 165.05263157894737
# prob: 0.001005737878285638
# x: 7.3
# var:0.11296398891966761   feature: width   class: 0
# mean: 7.457894736842104
# prob: 0.0010693290287111508
# x: 9.7
# var:0.08033240997229923   feature: height   class: 0
# mean: 7.342105263157895
# prob: 1.4102625794579104e-18
# x: 0.72
# var:0.014612742382271475   feature: color_score   class: 0
# mean: 0.7836842105263158
# final prob: 4.052158151846622e-18
# pc: 0.3220338983050847
# prob times Pc: 1.304932286187895e-18
#
# prob: 1
# x: 196
# var:12.16   feature: mass   class: 1
# mean: 81.2
# prob: 5.17371149463989e-237
# x: 7.3
# var:0.022400000000000034   feature: width   class: 1
# mean: 5.9399999999999995
# prob: 1.6200949953194553e-254
# x: 9.7
# var:0.0616   feature: height   class: 1
# mean: 4.380000000000001
# prob: 0.0
# x: 0.72
# var:0.0002240000000000004   feature: color_score   class: 1
# mean: 0.796
# final prob: 0.0
# pc: 0.0847457627118644
# prob times Pc: 0.0
#
# prob: 1
# x: 196
# var:5136.797783933517   feature: mass   class: 2
# mean: 193.78947368421052
# prob: 0.005565028336142887
# x: 7.3
# var:0.6277008310249305   feature: width   class: 2
# mean: 7.557894736842104
# prob: 0.0026582926980722827
# x: 9.7
# var:0.5612742382271466   feature: height   class: 2
# mean: 7.936842105263156
# prob: 8.878170730207409e-05
# x: 0.72
# var:0.0007988919667590031   feature: color_score   class: 2
# mean: 0.7710526315789474
# final prob: 0.00024527909468089956
# pc: 0.3220338983050847
# prob times Pc: 7.898818303283205e-05
#
# prob: 1
# x: 196
# var:1317.5   feature: mass   class: 3
# mean: 150.0
# prob: 0.004924824282973006
# x: 7.3
# var:0.36609375   feature: width   class: 3
# mean: 6.512499999999999
# prob: 0.0013924231230774374
# x: 9.7
# var:0.9337109374999999   feature: height   class: 3
# mean: 8.856250000000001
# prob: 0.0003927532936392705
# x: 0.72
# var:0.00010273437500000018   feature: color_score   class: 3
# mean: 0.718125
# final prob: 0.015200267402296545
# pc: 0.2711864406779661
# prob times Pc: 0.0041221064141821135
#
# [1.304932286187895e-18, 0.0, 7.898818303283205e-05, 0.0041221064141821135]
# prob: 1
# x: 216
# var:135.73407202216066   feature: mass   class: 0
# mean: 165.05263157894737
# prob: 2.410917476233981e-06
# x: 7.3
# var:0.11296398891966761   feature: width   class: 0
# mean: 7.457894736842104
# prob: 2.563355819469126e-06
# x: 10.2
# var:0.08033240997229923   feature: height   class: 0
# mean: 7.342105263157895
# prob: 3.0169937967595186e-28
# x: 0.71
# var:0.014612742382271475   feature: color_score   class: 0
# mean: 0.7836842105263158
# final prob: 8.270803389969966e-28
# pc: 0.3220338983050847
# prob times Pc: 2.663479057786938e-28
#
# prob: 1
# x: 216
# var:12.16   feature: mass   class: 1
# mean: 81.2
# prob: 0.0
# x: 7.3
# var:0.022400000000000034   feature: width   class: 1
# mean: 5.9399999999999995
# prob: 0.0
# x: 10.2
# var:0.0616   feature: height   class: 1
# mean: 4.380000000000001
# prob: 0.0
# x: 0.71
# var:0.0002240000000000004   feature: color_score   class: 1
# mean: 0.796
# final prob: 0.0
# pc: 0.0847457627118644
# prob times Pc: 0.0
#
# prob: 1
# x: 216
# var:5136.797783933517   feature: mass   class: 2
# mean: 193.78947368421052
# prob: 0.005306649637686723
# x: 7.3
# var:0.6277008310249305   feature: width   class: 2
# mean: 7.557894736842104
# prob: 0.002534870827426518
# x: 10.2
# var:0.5612742382271466   feature: height   class: 2
# mean: 7.936842105263156
# prob: 1.4087072549863765e-05
# x: 0.71
# var:0.0007988919667590031   feature: color_score   class: 2
# mean: 0.7710526315789474
# final prob: 1.9294960534693137e-05
# pc: 0.3220338983050847
# prob times Pc: 6.213631358629993e-06
#
# prob: 1
# x: 216
# var:1317.5   feature: mass   class: 3
# mean: 150.0
# prob: 0.0021047437352365596
# x: 7.3
# var:0.36609375   feature: width   class: 3
# mean: 6.512499999999999
# prob: 0.0005950859719459
# x: 10.2
# var:0.9337109374999999   feature: height   class: 3
# mean: 8.856250000000001
# prob: 9.344623525135087e-05
# x: 0.71
# var:0.00010273437500000018   feature: color_score   class: 3
# mean: 0.718125
# final prob: 0.002668015917477428
# pc: 0.2711864406779661
# prob times Pc: 0.0007235297403328618
#
# [2.663479057786938e-28, 0.0, 6.213631358629993e-06, 0.0007235297403328618]
# mine: [1, 1, 2, 2, 1, 1, 3, 1, 4, 4]
# sklearn: [1 1 2 2 1 3 3 3 4 4]
